# %% [markdown]
# # Python 網頁爬蟲與資料視覺化應用 Final Project
# ## 成大通識與各系必修撞課分析
# 作者：物理系 施宇庭 C24066096
#
# 1. [問題定義](#問題定義)
# 2. [資料收集](#資料收集)
# 3. [資料前處理](#資料前處理)
# 4. [視覺化呈現](#視覺化呈現)
# 5. [結果分析與討論](#結果分析與討論)

# %% [markdown]
# ## 問題定義
# [回頂部](#成大通識與各系必修撞課分析)

# %% [markdown]
# 選課季節又到了，，但因為和系上必修撞課，很難選到又甜又涼的通識，，，因此，這次期末專題打算來做各系必修與通識的撞課情況分析
#
# 統計各個科系必修的上課時間中有多少通識撞課，
#
# 備註：研究所不需要修通識課，因此這份報告將專注在大學部的部分
#
# 希望藉由這份分析找出，提供各系及通識中心排課參考，以平衡各系學生選擇通識課程的權益

# %% [markdown]
# ## 資料收集
# 資料來源：[NCKU Open Data Platform](http://data.ncku.edu.tw/dataset/8d6462ee513f1c1a601506265cc9f674)
#
# 可從上方連結下載資料，或是直接執行專案目錄下的 `get_data.sh` 來下載資料，預設儲存路徑為 `data/`
# ```bash
# source get_data.sh [儲存路徑]
# ```
#
# **注意：若自行給定下載路徑，則下方程式碼的路徑也要記得修改**
#
# [回頂部](#成大通識與各系必修撞課分析)

# %% [markdown]
# 匯入所需套件

# %%
import pandas as pd

# %% [markdown]
# 載入資料並觀察，由於資料的完整性，我們先拿106學年度第2學期的資料進行分析

# %%
path = './data/1062.csv'
df = pd.read_csv(path, encoding='cp950')
df.head(3)
# Out:
#    學年度 設立別  學校類別  學校代碼    學校名稱  學期別  開課單位   學制      課程代碼    課程名稱  ...   結束時間  \
# 0  106  公立  一般大學     5  國立成功大學    2  外國語言  大學部  A1107001   跨文化溝通  ...  11:00
# 1  106  公立  一般大學     5  國立成功大學    2  外國語言  大學部  A1106002  基礎學術溝通  ...  11:00
# 2  106  公立  一般大學     5  國立成功大學    2  外國語言  大學部  A1105003  基礎學術英文  ...  11:00
#
#    重複間隔  週次      課程類別 授課教師 學程名稱及類別 授課語言        上課地點  課程期程別   備註
# 0    每週 NaN  通識(外國語言)  鍾淑玫     NaN   中文  修齊大樓 26304     一般  模組一
# 1    每週 NaN  通識(外國語言)  賴諭萱     NaN   中文  修齊大樓 26104     一般  模組一
# 2    每週 NaN  通識(外國語言)  辛佳玲     NaN   中文  修齊大樓 26105     一般  模組一
#
# [3 rows x 26 columns]

# %% [markdown]
# ## 資料前處理
# 1. 查看資料中是否包含所有我們需要的欄位
# 2. 處理缺失值(missing value)
# 3. 處理重複值(duplicate value)
# 3. 最後刪除掉不必要的欄列資料
#
# [回頂部](#成大通識與各系必修撞課分析)

# %% [markdown]
# 先針對資料做更仔細的觀察，以下是重點關注的欄位
#
# 主要分析的欄位有5個：
# - **開課單位**：判斷是否屬於必修或通識
# - **星期**、**開始時間**、**結束時間**：判斷有無撞課
# - **課程類別**：依照不同領域的通識做更細部的分析
#
# 幫助我們篩選資料的欄位有2個：
# - **學制**：篩選出大學部的課程
# - **必選修**：只保留必修部分(各系必修和通識都算必修)
#
# 其餘欄位都不重要，可以捨棄
#
# > 備註：有些研究所會開課給大學部學生，例如大碩合開，因此以學制篩選資料，會看到開課單位還是有研究所

# %%
df.columns
# Out:
# Index(['學年度', '設立別', '學校類別', '學校代碼', '學校名稱', '學期別', '開課單位', '學制', '課程代碼',
#        '課程名稱', '必選修', '學分數', '起始日期', '結束日期', '星期', '開始時間', '結束時間', '重複間隔',
#        '週次', '課程類別', '授課教師', '學程名稱及類別', '授課語言', '上課地點', '課程期程別', '備註'],
#       dtype='object')

# %% [markdown]
# 檢查缺失值，並顯示有缺失值的欄位，這裡我們只在乎上面提到的重要欄位，恰好只有「開始時間」和「結束時間」需要處理

# %%
print(df.isnull().sum())
df[df.isnull()['開始時間']]
# Out:
# 學年度           0
# 設立別           0
# 學校類別          0
# 學校代碼          0
# 學校名稱          0
# 學期別           0
# 開課單位          0
# 學制            0
# 課程代碼          0
# 課程名稱          0
# 必選修           0
# 學分數           0
# 起始日期          0
# 結束日期          0
# 星期            0
# 開始時間          1
# 結束時間          1
# 重複間隔          0
# 週次         4989
# 課程類別          0
# 授課教師          0
# 學程名稱及類別    4580
# 授課語言          0
# 上課地點        379
# 課程期程別         0
# 備註         2621
# dtype: int64
#       學年度 設立別  學校類別  學校代碼    學校名稱  學期別  開課單位   學制      課程代碼  課程名稱  ... 結束時間  \
# 4397  106  公立  一般大學     5  國立成功大學    2  管理學院  大學部  RZ30100Y  精實創業  ...  NaN
#
#       重複間隔  週次 課程類別 授課教師 學程名稱及類別 授課語言 上課地點  課程期程別                         備註
# 4397    每週 NaN   基礎  楊朝旭     NaN   中文  NaN     一般  上課教室技轉育成中心大會議室，上課時間詳如課程大綱
#
# [1 rows x 26 columns]

# %% [markdown]
# 很幸運只有1列資料有缺失值，接著開始清理

# %%
print(f'before size: {df.shape}')
df.dropna(subset=['開始時間'], inplace=True)
print(f'after size: {df.shape}')
# Out:
# before size: (4989, 26)
# after size: (4988, 26)

# %% [markdown]
# 檢查重複值

# %%
repeated = df[df.duplicated(keep=False)]
print(f'重複 {len(repeated.index)} 列')
repeated.head(4)
# Out:
# 重複 20 列
#       學年度 設立別  學校類別  學校代碼    學校名稱  學期別      開課單位   學制     課程代碼 課程名稱  ...  \
# 1051  106  公立  一般大學     5  國立成功大學    2  生命科學系學士班  大學部  C541100  生態學  ...
# 1052  106  公立  一般大學     5  國立成功大學    2  生命科學系學士班  大學部  C541100  生態學  ...
# 1065  106  公立  一般大學     5  國立成功大學    2  生命科學系學士班  大學部  C541100  生態學  ...
# 1066  106  公立  一般大學     5  國立成功大學    2  生命科學系學士班  大學部  C541100  生態學  ...
#
#        結束時間  重複間隔  週次 課程類別                 授課教師 學程名稱及類別 授課語言       上課地點  \
# 1051  12:00    每週 NaN   基礎  李亞夫*;邱慈暉 ;陳一菁 ;仲澤剛史     NaN   中文  生科系館 3404
# 1052  10:00    每週 NaN   基礎  李亞夫*;邱慈暉 ;陳一菁 ;仲澤剛史     NaN   中文  生科系館 3404
# 1065  12:00    每週 NaN   基礎  李亞夫*;邱慈暉 ;陳一菁 ;仲澤剛史     NaN   中文  生科系館 3404
# 1066  10:00    每週 NaN   基礎  李亞夫*;邱慈暉 ;陳一菁 ;仲澤剛史     NaN   中文  生科系館 3404
#
#       課程期程別   備註
# 1051     一般  NaN
# 1052     一般  NaN
# 1065     一般  NaN
# 1066     一般  NaN
#
# [4 rows x 26 columns]

# %% [markdown]
# 清理重複值，重複的列中只保留一列，因此清除掉10列

# %%
print(f'before size: {df.shape}')
df.drop_duplicates(keep='first', inplace=True)
print(f'after size: {df.shape}')
# Out:
# before size: (4988, 26)
# after size: (4978, 26)

# %% [markdown]
# 檢查看看哪些欄位沒有意義可以刪除

# %%
for col in df.columns:
    print(f'{col}\n{df[col].unique()}\n')
# Out:
# 學年度
# [106]
#
# 設立別
# ['公立']
#
# 學校類別
# ['一般大學']
#
# 學校代碼
# [5]
#
# 學校名稱
# ['國立成功大學']
#
# 學期別
# [2]
#
# 開課單位
# ['外國語言' '體育室' '軍訓室' '教育學程' '計網中心' '服務學習（三）' '基礎國文' '通識中心' '共同科目英語授課'
#  '華語中心' '大一全校不分系學士學位學程' '文學院學士班' '中國文學系學士班' '外國語文學系學士班' '歷史學系學士班'
#  '台灣文學系學士班' '數學系學士班' '物理學系學士班' '化學系學士班' '地球科學系學士班' '生命科學系學士班'
#  '生物科技與產業科學系學士班' '法律學系學士班' '政治學系學士班' '經濟學系學士班' '心理學系學士班' '機械工程學系學士班'
#  '電機工程學系學士班' '化學工程學系學士班' '資源工程學系學士班' '材料科學及工程學系學士班' '土木工程學系學士班' '建築學系學士班'
#  '水利及海洋工程學系學士班' '工程科學系學士班' '能源國際學士學位學程學士班' '系統及船舶機電工程學系學士班' '都巿計劃學系學士班'
#  '工業設計學系學士班' '航空太空工程學系學士班' '環境工程學系學士班' '測量及空間資訊學系學士班' '資訊工程學系學士班'
#  '光電科學與工程學系學士班' '生物醫學工程學系學士班' '會計學系學士班' '統計學系學士班' '工業與資訊管理學系學士班'
#  '企業管理學系學士班' '交通管理科學系學士班' '護理學系學士班' '醫學檢驗生物技術學系學士班' '醫學系學士班' '物理治療學系學士班'
#  '職能治療學系學士班' '藥學系學士班' '中國文學系中國文學碩、博士班' '外國語文學系碩、博士班' '歷史學系碩、博士班'
#  '藝術研究所碩士班' '台灣文學系碩、博士班' '考古學研究所' '戲劇碩士學位學程' '數學系應用數學碩、博士班' '物理學系碩、博士班'
#  '化學系碩、博士班' '地球科學系碩、博士班' '生命科學系碩、博士班' '生物科技與產業科學研究所碩、博士班' '光電科學與工程學系碩、博士班'
#  '太空與電漿科學研究所碩、博士班' '理學院研究所' '工程管理碩士在職專班' '機械工程學系碩、博士班' '電機工程學系碩、博士班'
#  '化學工程學系碩、博士班' '資源工程學系碩、博士班' '材料科學及工程學系碩、博士班' '土木工程學系碩、博士班' '建築學系碩、博士班'
#  '水利及海洋工程學系碩、博士班' '工程科學系碩、博士班' '海洋科技與事務研究所碩、博士班' '尖端材料國際碩士學位學程'
# 結束時間
# ['11:00' '15:00' '12:00' '17:00' '10:00' '未定' '19:00' '18:00' '14:00'
#  '13:00' '16:00' '20:00' '09:00' '21:00' '08:00' '22:00']
#
# 重複間隔
# ['每週' '每日']
#
# 週次
# [nan]
#
# 課程類別
# ['通識(外國語言)' '基礎' '通識(基礎國文)' '通識(人文學)' '通識(自然與工程科學)' '通識(社會科學)'
#  '通識(生命科學與健康)' '通識(科際整合)' '通識(融合通識)' '通識(生命科學)' '通識(公民與歷史)']
#
# 授課教師
# ['鍾淑玫' '賴諭萱' '辛佳玲' ... '張文綺*;蔡文杰 ;黃兆立' '李瑞花 ;蘇百祥*;黃兆立'
#  '黃浩仁 ;詹明才 ;張文綺*;方素瓊 ;蘇百祥 ;黃兆立 ;林耀正 ;劉明容']
#
# 學程名稱及類別
# [nan '東南亞文化學分學程 (學分學程)' '性別研究學分學程 (學分學程)' '新聞與傳播學程 (學分學程)'
#  '美學與藝術跨域學分學程 (學分學程)' '醫學、科技與社會學程(STM) (學分學程)'
#  '醫學、科技與社會學程(STM) (學分學程);歷史與科技社會學分學程 (學分學程)' '應用哲學學程 (學分學程)' '戲劇學程 (學分學程)'
#  '戲劇學程 (學分學程);美學與藝術跨域學分學程 (學分學程)' '歷史與科技社會學分學程 (學分學程)'
#  '創意、創新、創業學程(三創學程) (學分學程)' '服務科學與體驗 (學分學程)'
#  '創意、創新、創業學程(三創學程) (學分學程);美學與藝術跨域學分學程 (學分學程)' '奈米積體電路工程碩士班學分學程 (學分學程)'
#  '太空科學與工程學分學程 (學分學程)' '電漿學分學程 (學分學程);太空科學與工程學分學程 (學分學程)'
#  '再生醫學科技學分學程 (學分學程)' '防災科技管理學分學程 (學分學程)' '跨維綠能材料學程 (學分學程)'
#  '人工智慧學分學程 (學分學程)' '電漿學分學程 (學分學程)' '再生醫學科技學分學程 (學分學程);跨維綠能材料學程 (學分學程)'
#  '鐵道運輸 (學分學程)' '奈米先進技術與設備學分學程 (學分學程)' '創意設計學程 (學分學程)'
#  '防災科技管理學分學程 (學分學程);太空科學與工程學分學程 (學分學程)' '防災科技管理學分學程 (學分學程);電漿學分學程 (學分學程)'
#  '繪圖與視訊技術學程 (學分學程)' '跨學門民航學分學程 (學分學程)' '跨學門民航學分學程 (學分學程);鐵道運輸 (學分學程)'
#  '生物科技學程 (學分學程)'
#  '醫學、科技與社會學程(STM) (學分學程);性別研究學分學程 (學分學程);歷史與科技社會學分學程 (學分學程)'
#  '醫療器材與系統學程 (學分學程)' '再生醫學科技學分學程 (學分學程);生物科技學程 (學分學程)'
#  '奈米先進技術與設備學分學程 (學分學程);電漿學分學程 (學分學程)'
#  '奈米積體電路工程碩士班學分學程 (學分學程);奈米先進技術與設備學分學程 (學分學程)'
#  '生物科技學程 (學分學程);醫療器材與系統學程 (學分學程)' '老化與生活 (學分學程)']
#
# 授課語言
# ['中文' '英文']
#
# 上課地點
# ['修齊大樓 26304' '修齊大樓 26104' '修齊大樓 26105' '修齊大樓 26103' '修齊大樓 26102'
#  '科際整合相關領域：人文學、社會科學' '104學年度(含)以前入學生為「哲學與藝術」' '跨領域通識'
#  '領域通識，限大學部學生，不接受特殊因素人工加簽' '科際整合相關領域：社會科學、生命科學與健康'
#  '英語授課,104學年度(含)以前入學生為「哲學與藝術」' '茶道與日本文化，104學年度(含)以前入學生為「公民與歷史」'
#  '科際整合相關領域: 人文學、社會科學、自然與工程科學、生命科學與健康' '相關領域：社會科學、自然與工程科學'
#  '科際整合領域 相關領域：人文學、社會科學、生命科學與健康' '第一堂課一定要到，科際整合相關領域：人文學、生命科學與健康'
#  '科際整合相關領域：人文學、自然與工程科學' '與李旺龍老師合開遠距教學'
#  '為MOOCS磨課師課程,104學年度(含)以前入學生為「哲學與藝術」' '過去與現代的對話,104學年度(含)以前入學生為「公民與歷史」'
#  'MOOCS，領域通識' '領域通識，普物實驗室35221' '英語授課，科際整合相關領域：人文、社會科學、生命科學與健康'
#  '上課教室：成大藝坊；科際整合相關領域：人、社。至少修過2門進階實作實習課程。請於選課期間至藝術中心登記'
#  '領域通識；選課學生至少具備台語聽力程度，能理解教師及學生之日常對談。' '科際整合相關領域：自然與工程科學、生命科學與健康'
#  '科際整合相關領域：人文學、社會科學、生命科學與健康' '相關領域：人文學、生命科學與健康'
#  '請於第16週前，持手冊至通識教育中心，經審查達18個合格積點後方可選課'
#  '請於第16週前，持手冊至通識教育中心，經審查達9個合格積點後方可選課'
#  'Moocs課程,修課同學需主動善用Moodle信箱接收重要通知（含開通步驟、修課須知與評量方法)' '限一年級修習'
#  '密集課程。中文班，凡106學年度入學之大一新生必修，詳情請閱讀課程查詢之課程公告聯結網址'
#  '密集課程。英文班，凡106學年度入學之大一外籍新生必修'
#  '密集課，中文系表演教室，7/2~7/6，7/9~7/12,8:00~17:00 科際整合領域，領域:人、社、自、生'
#  '密集授課，C-HUB教室，7/2(一)~7/6(五)，7/9(一)~7/12(四)8:~17:00科際整合領域，領域:人、社、自、生'
#  '密集授課，建築系美術教室，7/2(一)~7/6(五)，7/9(一)~7/12(四)8:~17:00科際整合領域，領域:人、社、自、生'
#  '密集課程，4/19(四)~4/20(五)9:00~18:00科際整合領域，領域:人、社、自'
#  '密集授課。104學年度(含)以前入學生為「哲學與藝術」。授課時間詳看課綱備註'
#  '英語授課；上課時間(二)18:10-19:40及(四)18:10-19:40'
#  'Level 1課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  'Level 2 課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  'Level 2課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  'Level 5 課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  'Level 6課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  'Level 4課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  'Level 8課程，非經華語中心(ext.52040)認定分級之外籍生，無法選此課程。'
#  '密集授課 3/10.3/11 9:00-17:00 3/17 13:00-17:00'
#  '(全英授課)密集授課，(3/31-4/1)9:00-18:00'
#  '(全英授課)密集授課，(4/28-4/29)9:00-18:00 C-Hub教室'
#  '(全英授課)密集授課，(5/26-5/27)9:00-18:00 C-Hub教室'
#  '(全英授課)密集授課，(6/30-7/1)9:00-18:00 C-Hub教室'
#  '密集授課，由業界專家葉肇元共同授課(3/3.3/17.4/14.4/28)9:00-18:00 C-Hub教室'
#  '密集授課(3/31) C-Hub教室' 'C-Hub教室'
#  '密集授課，上課時間為1/22、1/23、1/25，上午9點至下午4點，共3天。歡迎外系加選，加選請至教發中心網頁不分系公告。限選30人'
#  '密集授課5/5~6/30 8:00~12:00 C-Hub教室' '4/29~5/1澎湖田野調查'
#  '本課程屬創意三角洲開設之密集課程，僅開放已參與課程之學生選修。1/23 2-8 1/24 3-9 1/25 2-8'
#  '單號為甲組(學號倒數第二位)' '雙號為乙組(學號倒數第二位)' '單號為甲組 (學號倒數第二位)' '限20人選修'
#  '外文系館，外文大一生必修，含"掃除服務"及"社區服務"' 'Ａ組，限本系，須依上學期組別選課' 'Ｂ組，限本系，須依上學期組別選課'
#  'Ｃ組，限本系，須依上學期組別選課' 'Ｄ組，限本系，須依上學期組別選課' '五選一必修，大一日文組必修' '五選一必修，大一法文組必修'
#  '五選一必修，大一德文組必修' '五選一必修，大一西文組必修' '星期一中午N~6節上課(12:10~15:00)'
#  'A組，限本系，須依第一學期組別選課。' 'B組，限本系，須依第一學期組別選課，外籍教師。' 'C組，限本系，須依第一學期組別選課。'
#  'B組，限本系，須依第一學期組別選課。' 'D組，限本系，須依第一學期組別選課。' '大二日文組必修' '大二法文組必修' '大二西文組必修'
#  '大二德文組必修' '文學選修Literature，外籍教師' '語言學選修Linguistics，星期二5~7上課(13:10~16:00)'
#  '語言學選修Linguistics，星期三3~N上課(10:10~13:00)' '大三日文組必修' '大三法文組必修' '大三西文組必修'
#  '大三德文組必修' 'A組，選修課，大三大四學生優先' 'B組，選修課，大三大四學生優先'
#  '文學選修Literature；自維多利亞時期起至二十世紀之後' '星期三中午N~6節上課(12:10~15:00)'
#  '語言學選修Linguistics，電腦教室上課' '語言學選修Linguistics' '大三大四學生優先選課'
#  '星期四10~13:00上課，大三大四學生優先選課' '文學選修Literature，星期二5~7上課(13:10~16:00)' '新聞學程'
#  '進階日文選修，搭配第二外語畢業公演。' '基礎課程。自105學年入學適用，4選2，多修計為世界史領域' '基礎課' '基礎課,開放承認外系歷史'
#  '世' '台' '中' '基礎課，98新生開始必修' '進階，開放承認外系歷史(外系修一學期可承認)，台' '進階。台，中' '世界史'
#  '由本系老師指導，並取得指導教授同意' '中，外系可承認為通識學分' '未聽滿十場次者，請先辦理棄選。' '彈性密集課程，上課時間參歷史系網公告'
#  '「台語，客語，原住民語等三選二」' '「台文系學生須上、下學期課程皆修習通過始得計入畢業學分」' '第一堂課一定要來上課。'
#  '密集授課，上課時間：3/27、4/10、4/17、4/24、5/1、5/8 18:00~21:00' '限數二修習'
#  '額外加強時間暫定星期五第N節' '理化大樓二樓' '理化大樓一樓' '上課時間及教室，請注意moodle之通知、或系網的公告。'
#  '物理系光電組必修。與光電系合班上課' '物理系光電組必修，物理組學生若不拿課請自行退選。' '物理系物理組必修，光電組學生若不拿課請自行退選。'
#  '物理組必修' '修過量物及相對論的同學，皆不可選修近代物理概論。' '物理系光電組必修，物理組選修。' '物理系學生優先選課。' '近物實驗室'
#  '原課程名稱: 熱學(二)' '上課時間為(二)N (四)N；教室49116'
#  '上課時間: 107/05/21-107/06/29 星期三第8節 星期五56 教室49312'
#  '上課時間: 107/02/26-107/04/06 星期三第89節 星期五56 教室49312'
#  '上課時間:107/04/09-107/05/18 星期三第8節 星期五56 教室49312'
#  '屬『太空科學與工程學分學程』。可選課名單於第一堂課決定，欲選課同學請務必出席第一堂課。' '有機實驗室' '綜合實驗室'
#  '都計系與地科系合班，於地科系教室上課。' '野外地質訓練實施時間另行公告。' '與資源系合開' '歡迎生技產業系、生科系大二以上同學選修'
#  '本課程預定於107年4-6月密集授課' '本課程預計於107年7月在馬來西亞Pasoh雨林永久樣區密集授課'
#  '歡迎修過普通生物學相關課程且學期成績60分以上之大二至大四同學選修' '合班上課'
#  '學號倒數第2碼為單數之單數班，全體學生「第1階段選課」限學號倒數第2碼為單數者可選此班，違者必須退選，換班自第2階段選課開始'
#  '學號倒數第2碼為雙數之雙數班，全體學生「第1階段選課」限學號倒數第2碼為雙數者可選此班，違者必須退選，換班自第2階段選課開始' '特別法'
#  '專題及實例研討' '特別法(與水利系合開)' '合班上課。非以本課程為必修課程學分者，才可計入系定專業選修「專題及實例研討」學分。'
#  '法學外文' '法律系相鄰學科' '自106學年度起調整為下學期開授之3學分課程。' '與經濟系合班。' '系所處樓層暨所轄公共區域。'
#  '另安排於院電腦教室上課。' '「政治理論與方法」領域課程，限二年級以上同學選修。' '「國家行政與治理」領域課程，限二年級以上同學選修。'
#  '「全球與區域政治」領域課程，限二年級以上同學選修。' '非屬領域課程，限二年級以上同學選修'
#  '都計與政治、建築等三系合班。具服務學習內涵課程。' '上機地點： 社科院80303電腦教室' '上機地點：社科院80303電腦教室'
#  '擋修課程個體經濟學(一)或個體經濟學(二)，不能選課同學煩請洽系辦。' '限大三以上' '星期五，第2節：社科院80303電腦教室'
#  '大碩課程' '上機地點：社科院80303電腦教室/大碩課程' '英語授課外籍教師 Barczyk Daniel'
#  '建議先修過心理學教育統計學(一)' '本課程限40人修課，與醫工系合班上課 。' '未修過先修科目與心概者，需徵得授課老師同意後始可加簽。'
#  '心理系與醫工系合班' '請欲選課學生至系辦加簽並登記指導老師' '建議心理系或雙主修/輔系心理系者 (保留9-12時間機動上課)'
#  '建議修過心理測驗' '大碩合開課程。建議具備微積分與R程式之基礎' '選課前須先寫信取得授課老師同意' '大班合班上課' '分組小班研討'
#  '部分實習 91602' '機械丙化工丙合班上課分組研討' '材料:91Y04固力:91605' '第一階段不受理選課(第二階段開放選課)'
#  '實習91X02 講解教室另定' '星期二地點為91308教室，星期五地點為91203教室' '第一階段不受理選課，第二階段開放選課'
#  '第一階段不受理選課、第二階段開放選課' '工學院次專長學程 (第一階段不受理選課，第二階段開放選課)'
#  '本課程涉及實作、考量設備之數量限制，僅可供應20位名額(大三優先)將於選課第二階段結束後依照選課順序公佈修課名單。'
#  '第8節用91601電腦教室' '自行找教授簽"指導教授確認單"(系網下載)，於當學期第三階段選課前繳至系辦。' '博士班學生可修'
#  '大一甲乙丙合班' '第一節電腦教室B實習' '本系必選' '大一乙丙合班' '第一節電腦教室A實習' '大一甲丙合班'
#  '6選3實驗課(106學年度起入學適用)' '大二甲丙合班' '大二乙丙合班' '英文授課' '限大學部選修' '大二三合班'
#  '大二三合班，英語授課' '大二三合班(實驗儀器限制60人)' '微電子所與材料組(自選老師)，本系必選'
#  '電機所其他各組 (自選老師)，本系必選' '電腦與通訊網路組 (自選老師)，本系必選' '大三四合班' '大三四合班，英語授課'
#  '大四碩士合班' '化工一甲乙合班上課分組研討' '化工一丙、機械一丙合班上課分組研討' '在理化大樓一樓上課'
#  '請洽系館一樓93125室陳助教' '碩士班限乙組生選修' '化工二、三、四年級合開' '按分組名單選課'
#  '請至系網頁下載指導教授同意書並於開學後補棄選前繳至93556室' '每生必選' '化工三、四年級合開' '土木甲乙合班' '甲乙合班'
#  '碩士、碩專與大學四年級合班，博士班不能選修' '系館' '卓群大樓B1 47X39' '三四年級可選修，土木甲乙合班' '瀝青實驗室'
#  '三四年級可選修，土木甲乙合班，鐵道運輸學分學程合班' '大四、碩士及碩專班合班，博士班不能修本課程。密集式授課，隔周上課。'
#  '英語授課，大四、碩士及碩專班合班，博士班不能修本課程' '及5112教室，須同時選修建築敘事'
#  '彈性課程約寒假、春假、期末各連續上2天;本課程於建築設計組為必修、建築工程組為必選。' '及5101、5124教室'
#  '本科如不及格將擋建築構造(二)' '本課程於建築設計組為選修，未來欲選修該組同學可不修，請於第三階段棄選。' '須同時選修建築設計四'
#  '及5122教室' '本課程於建築工程組為選修。' '本課程於建築設計組為選修。' '本科如未修習將擋大四上「建築職業實務」；限建築設計組選修'
#  '及5103教室' '修畢大三建築設計後實習日數至少30天以上，實習日數計算詳辦法，累計應達60日' '限工程組選修' '本課程為彈性密集課程。'
#  '限設計組選修' '水利系2樓電腦教室' '1.此課程非水利系設計必修四選二課程。 2.彈性課程密集式授課。' '水利系電腦教室上課'
#  '四科任選二科之設計必修' '星期二第78節於41104上課，星期四第4節於41107上課' '大學部必選課程'
#  '本課程前三週依時段授課，其餘將安排於暑期107/7/20~31密集進行，並與香港理工大學學生共同上課及實地參訪。'
#  '星期二第2節41104上課、星期三第3~4節41107上課' '能源學程與航太系合開'
#  '欲修課者請於系網下載論文登記表，並於3/8前繳至系辦公室' '航太系與能源學程合開。' '船舶科技組選修' '系館實驗室' '機電控制組選修'
#  '選課請洽系辦並繳交大學部論文指導同意書' '上課地點：電腦教室、電工實驗室' '船舶組與機電組專業共同選修' '須修過「基本設計(一)」'
#  '須修過「都市規劃與設計實習(一)」' '都計二、三合班' '須修過「都市規劃與設計實習(三)」' '須修過「經濟學」'
#  '具服務學習內涵課程，實際上課時間與社區服務時間詳見課程大綱。' '須修過都市規劃與設計實習(四)' '須已完成本系同意之校外實習30天以上。'
#  '須修過「論文(一)」' '密集授課，上課時間地點依課程大綱及公告辦理。修課請洽助教室。' '上課教室為C-HUB一樓電腦教室5102'
#  '1.納入「創意設計學程」2.「創意設計學程」學生請至創意設計教學資源中心加簽' '服務科學與體驗學程' '電子實驗室' '民航工程學程'
#  '理化大樓2樓' 'PC教室75309' '組課程必選。' '水利系館流力實驗室' '環工系後館3樓環境分析實驗室'
#  '組課程必選。(與水利系合班，上課教室在水利系4F演講廳）' 'A班與B班，二選一' '本課程須經授課教師同意加簽'
#  '學生可就興趣洽請系上任何老師指導' '週四第9節為實習課，不得衝堂' '1.甲乙合班' '必選 (須修過方能畢業)' '本課程為大碩合開'
#  '本課程為大碩合班,與醫資所及製造所合班英語授課' '大碩合開' '大碩合班' '第一階段限本系學生選課' '會計系大一必選' '打掃會計系館'
#  '會計系大二必選' '研究所先修課程' '若使用電腦教室時將改至63205上課' '會計系大三必選' '會計系大四必選' '統計系與會計系合開'
#  '企管系與會計系合開' '建議三年級以上選課。企管系與會計系合開' '物流管理領域必修 交管與會計系合開' '交管系與會計系合開'
#  '週三第1節另有1節實習課' '週三第6節另有1節實習課' '週五第3節另有1節實習課' '週五第1節另有1節實習課' '統計系與企管系合開'
#  '交管系與工管系合班' '週四第９堂實習課不得衝堂61201' '週二第９堂實習課不得衝堂61101' '週三第 9 堂實習課不得衝堂61201'
#  '週一第９堂實習課不得衝堂61101' '開放給大三、大四學生' '電腦室' '運輸科技領域必修;鐵道運輸學分學程(選課須經本系登記審核通過)'
#  '旅客運輸領域必修,民航學分學程(選課須經本系登記審核通過)' '旅客運輸領域必修' '電信領域必修' '物流管理領域必修'
#  '民航及鐵道運輸學分學程(選課須經本系登記審核通過)' '先修:國際貿易 ;物流管理領域必修.' '鐵道運輸學分學程(選課須經本系登記審核通過)'
#  '104學年度起入學生必選;民航及鐵道運輸學分學程(選課須經本系登記審核通過).' '運輸科技領域必修' '與職治、物治合開' '限本系學生'
#  '限本系學生(國鼎臨床技能中心)' '限本系學生，寒假至海外見習' '醫院實習，限本系學生' '限本系學生，暑假醫院實習'
#  '醫技系與醫工系合班上課' '與物治系合班' '多位教師合授, 4F實驗室' '4F實驗室' '實驗室5791' '5791實驗室'
#  '醫學院三樓實驗室' '醫學院第三講堂' '3F實驗室' '建議須修過、或同時修習醫學生化(3學分)' '限本系' '需先修免疫學含實驗'
#  '需先修微生物學（含實驗）' '需先修生物化學（含實驗）' '請上課同學提早一小時至教室準備' '限醫學系' '限醫學系學生選修'
#  'Ｂ模組課程，每週上２小時，前半學期上課（3/1~5/3）' '限醫學系學生選修，2月26日課程及評分說明；6月25日期末問卷(點名)'
#  'B模組課程；於203D、208及醫圖210教室分組上課'
#  '寒假107年1月22日(一)至1月26日(五)全日密集班上課；由系辦統 一登錄選課名單；Ｂ模組課程' 'Ａ模組課程'
#  'Ａ模組課程；為融入服務學習內涵之專業課程' '限醫學系學生修讀' '學期中有安排校外學習活動' '醫學院第二講堂及三樓實驗室上課，多位老師合授'
#  'Ａ模組課程；全程英語授課；為融入服務學習內涵之專業課程' 'Ｂ模組課程' '與通識合班上課，醫學系學生不能抵通識'
#  '限醫學系三年級以上學生選修／其他系所選修需經開課老師同意' '醫學院四樓實驗室及第一講堂上課，多位教師合授'
#  '英語授課；物理所4選2必修，物理所主開。' '碩一必修。碩一，二及碩三以上合班。' '碩二必修。碩一，二及碩三以上合班。'
#  '大學部學生歡迎選修。' '歡迎大學部學生選修' '博一必修。物博一二及博三以上合班。' '博二必修。物博一二及博三以上合班。' '限碩班'
#  '隔週上課' '限博班' '限碩士在職專班選修' '限碩士在職專班二年級(含)以上選修' '供碩三及碩三以上學生選課' '博一二合班'
#  '供博三及博三以上學生選課' '生命所、與熱植所合班上課' '已修過光電子學(一)者為佳' '應先修光電實驗（一）' '碩一生' '博一生'
#  '博二生' '台積電主管開授，(一)、(二)都需修課始合計6畢業學分' '限光電所學生' '限本系研究生' '電漿所與機械所合開'
#  '彈性密集授課，開課時間：107/1/22(一)~107/1/26(五)，下午14:00 – 17:00 上課教室：地科系館1樓3017教室'
#  '彈性密集授課，開課時間：107/1/29(一)~107/2/2(五)，下午14:00 – 17:30(含30分鐘演習) 上課教室：成功校區理化大樓2樓普物實驗'
#  '彈性密集授課，開課時間：107/1/22(一)~107/1/26(五)，9:00-18:00 上課教室：成功校區理化大樓3樓35306教室、化學系館1樓3205'
#  '彈性密集授課，開課時間：107/1/29(一)~107/2/2(五)，9:00-18:00 上課教室：成功校區地科系館1樓3017教室及資源系教室'
#  '彈性密集授課，開課時間：107/1/29(一)~107/2/2(五)，9:00-18:00 上課教室：自強校區儀設大樓4樓95416室及B101室'
#  '上課教室:照坤精密儀設大樓4樓95416(工學院會議室)' '限本專班學生選課' '工程專班、製造所合開' '不分組' '碩博三（含）以上'
#  '須修過計算流體力學' '機械所與奈微所合開'
#  '英語授課(Programming skill and experience are necessary)' '電子材料組'
#  'VLSI/CAD組' '控制組' '電力組' '儀器系統組' '碩博碩專合班' '碩博、碩專合班' '電機資訊合班電機系四樓會議室'
#  '在職專班碩一' '在職專班碩二' '碩三博三以上必修' '化工所與能源國際工程碩士博士學程合班，化工所碩一甲組生必選英語授課'
#  '碩一甲組生必選中文授課' '英語授課，限104學年度(含)以後入學之碩士班乙組生或博士生符合畢業資格規定第6條者選修' '修過化工熱力學'
#  '碩博一學生欲擔任教學獎助生者必選該課程' '碩博二學生欲擔任教學獎助生者必選該課程' '僅供碩一甲組資源開發及地質選課'
#  '僅供碩一乙組資源材料及再生選課' '僅供碩一丙組資源管理及經濟選課' '僅供碩二甲組資源開發及地質選課' '僅供碩二乙組資源材料及再生選課'
#  '僅供碩二丙組資源管理及經濟選課' '僅供博一甲組資源開發與地質工程選課' '僅供博一乙組資源材料及再生選課' '僅供博一丙組資源管理及經濟選課'
#  '僅供博二甲組資源開發及地質工程選課' '僅供博二乙組資源材料及再生選課' '僅供碩三博三以上甲組資源開發及地質工程選課'
#  '僅供碩三博三以上丙組資源管理及經濟選課' '英語授課 尖端所與材料所合開' '碩ㄧ博ㄧ修習' '碩二博二修習'
#  '限碩三博三(延)以上選修，0學分' '限碩一以上選課' '中文授課' '教室另定，限碩、博士三年級以上研究生選讀'
#  '限碩博一或重修，結構工程組（二）（四）合班' '結構工程組（二）（四）合班' '限碩博一或重修，大地工程組（二）（四）合班'
#  '限碩博二或重修，大地工程組（二）（四）合班' '限碩博一或重修，交通工程組（二）（四）合班' '限碩博二或重修，交通工程組（二）（四）合班'
#  '限碩博一或重修，結構材料組（二）（四）合班' '限碩博二或重修，結構材料組（二）（四）合班' '限碩博一或重修，工程管理組（二）（四）合班'
#  '限碩博二或重修，工程管理組（二）（四）合班' '本系本學期開課教師都是授課教師，以系主任為代表'
#  '適合碩博二年級以上。本系本學期開課教師都是授課教師，以系主任為代表。' '碩博與碩專班合班' '碩博及碩專班合班' '碩博與碩專合班，英語授課'
#  '碩博與碩專班合班，乙組核心，英語授課。' '碩博與碩專合班' '碩博與碩專班合班，乙組核心。' '碩博與碩專班合班，英語授課'
#  '碩博與碩專班合班，丁組核心' '教室另定，限碩士專班三年級以上研究生選讀' '以下為甲組課程。上課教室：各老師研究室'
#  '上課教室：建築系綠色教室' '規劃組課程' '乙組課程' '以下為乙組課程；於各研究室上課，並須修畢研究所設計課'
#  '大學部學生須修過「近代建築史」才得選修本課程' '以下為規劃組課程' '以下為保存組課程' '限大學修畢建築構造或鋼筋混凝士及鋼骨構造'
#  '以下為工程組課程；碩博及碩專合開。' '本課程與碩專班合開' '碩博及碩專合開' '以下為環控組課程'
#  '第1節課將說明作業收集等，請務必準時參加' '科目序號：N7105限碩博三以上同學選修；N7305限碩專三以上同學選修。'
#  '與自災所合開，自災所學生及水利所外籍生優先選課，水利所國內生請以紙本加簽' '限延畢生修讀' '104學年度起入學碩士生四選二必修課程'
#  '上課地點：水利系2樓電腦教室' '自災所與水利所合開課程' '彈性課程密集式授課' '自災所、水利所、海事所合開課程'
#  '語言課程非本系研究生畢業學分' '限控制與通訊組研一' '限資訊與應用組研一' '限應用力學固力組研一' '限應用力學熱流組研一'
#  '限奈米生醫、量子電腦及系統整合組研一' '限控制與通訊組研二' '限資訊與應用組研二' '限應用力學固力組研二' '限應用力學熱流組研二'
#  '限奈米生醫、量子電腦及系統整合組研二' '限碩博班研二以上' '工科所醫工所合班' '限工科系碩專班甲組研一' '限工科系碩專班乙組研一'
#  '限工科系碩專班甲組研二' '限工科系碩專班乙組研二' '限工科系碩專班研二以上' '限工科系碩專班學生選修'
#  '限延畢生選課，延畢生每學期至少需選修一門課' '法律系與海事所合開，法律系比照「研討」課程。' '英語授課 尖端所與材料所合班'
#  '測量所與自災所合開課程' '碩博二以上選修' '資訊所醫資所製造所多媒學程公衛所合班' '資訊所醫資所多媒體學程製造所合班'
#  '資訊所多媒體學程合班' '資訊所醫資所多媒體學程合班' '資訊所醫資所多媒學程合班' '資訊所醫資所多媒體學位學程合班,大學部勿選'
#  '航太所與能源國際工程碩士博士學程合開' '航太所與能源工程國際碩士博士學程合開' '供博一二選修合班' '碩博修業三年(含)以上用'
#  '碩士班必選' '大學部學生限三年級以上且須修過都市設計與都市發展史'
#  '密集授課，上課時間地點依課程大綱及公告辦理。須修過「跨領域濱海陸地規劃實習(一)」。修課請洽授課教師。'
#  '密集授課，上課時間地點依課程大綱及公告辦理。大學部學生須先修都市設計及格。修課請洽授課教師。' '密集授課，上課時間地點依課程大綱及公告辦理。'
#  '密集授課，上課時間地點依課程大綱及公告辦理。本科為(二)解讀古地圖、(三)再現古地圖(預計107學年開課)之先修科目。' '公衛所與都計所合班'
#  '供碩、博三以上選修' '博一，甲組' '博一，乙組' '博一，丙組' '博一，丁組' '博二，甲組' '博二，乙組' '博二，丙組'
#  '博二，丁組' '碩一必修課，甲組' '碩一必修課，乙組' '碩一必修課，丙組' '碩一必修課，丁組' '碩二必選，甲組' '碩二必選，乙組'
#  '碩二必選，丙組' '碩二必選，丁組' '碩博一必修' '碩博二必修' '碩專一必修' '碩專二必修' '僅供碩專班三以上必修'
#  '碩一與碩二合班' '碩三與博合班（英語授課）' '2樓47207會議室，英語授課' '環醫所與環工所合班' '博一二合班（英語授課）'
#  '博碩三（含）以上學生選修\u3000' '資訊所製造所合班' '資訊所醫資所合班' '製造所、資訊所合班'
#  '製造所、資訊所合班，Moocs課程' '資訊所醫資所製造所體健所合班(運動科技產業領域專業選修課程)英語授課' '醫工所．口醫所合上'
#  '須先修完生物電化學，微機電與醫工所合班' '先修課程：醫學工程概論或臨床醫療概論' '博一、MDI及碩班外籍生(甲組)生物力學組學生選課'
#  '博一、MDI及碩班外籍生(乙組)醫電組學生選課' '博二、MDI及外籍生(甲組)生物力學組學生選課'
#  '博二、MDI及外籍生(乙組)醫電組學生選課' '生物力學組' '醫電組' '供碩三博三以上選課' '醫工所與國企所合班' '口醫所與醫工所合班'
#  'MDI必修課程/英文授課' '碩一博一合班' '碩二博二以上合班' '甲組核心' '丙組核心' '乙組核心' '甲組選修' '博班必修'
#  '碩班必修' 'C組選修' '密集授課(Intensice Course)第一階段不受理選課，請洽所辦人員辦理人工加選' '資訊與系統甲組'
#  '通訊與網路乙丙丁組' '參加3D多媒體研究計劃才可選修' '民航所碩一必修' '民航所碩二必修' '僅供民航所碩三以上必修'
#  '限修畢45學分以上選修' '限本所' '不開放網路選課，由系辦統一選課。' '大學部欲選修需經任課教師同意' '限研究所選修'
#  '限會計所及財金所一年級擔任研究生獎助學金的助理選修' '限會計所及財金所二年級擔任研究生獎助學金的助理選修'
#  '建議有意願讀博士班的研究所同學選修' '碩一選修' '碩二選修' '碩博三以上選修，碩博合開' '通過博士資格考後選修'
#  '工資所博一必修，與博二專討合班' '工資所博二必修，與博一專討合班' '本課程先修課程規定為:統計學(一)(二)及格'
#  '本課程先修課程為:統計學' '限在職專班三年級(含)以上選修' '碩一二合班' '延畢生修' '交管所與電信所合班' '先修:統計學'
#  '交電管合開' '選課經須本系登記審核通過' '旅客運輸領域必修,跨學門民航學分學程及鐵道運輸學程,選課須經本系登記審核通過.'
#  '跨學門民航學分學程 ，選課須經本系登記審核通過' '限碩專選修。' '限碩專班已修畢學分者選修' '限碩專班修讀' '一樣英語授課'
#  '限修過本所「國際企業研究方法」課程者選修，上課日期為3/1、3/15、3/29三次。' '資管所碩一必修' '資管所碩二必修'
#  '資管所博一必修，與博二專討合班' '資管所博二必修，與博一專討合班' '資管所博三以上選修，與博一博二專討合班'
#  '若非財金所學生，限修過初會、財務管理的同學選修' 'For NCKU Distinguished Scholarship Recipients'
#  '選修課程' 'PhD Fundamental Course' '方法學課程' '台北班課程' '共同必修'
#  '基礎專業：共同必修；碩一、碩二合班' '健康管理、運動科技產業領域專業選修課程' '健康管理領域核心專業課程(上課地點：中正堂視廳教室)'
#  '限碩士班三年級以上修，並修滿規定30學分以上修習。' '核心專業選修課程' '專業選修課程' '限本所。限修滿畢業學分者選修。'
#  '開放網路選課(全英文授課)／密集授課詳如課程大綱' '生科所，生化所，基醫所合班' '生化所，基醫所，口醫所合班' '生化，基醫合班'
#  '基醫所、分醫所、生化所合班上課' '上課教室:3樓實驗室' '多位老師合上' '藥理所，護理系合班 ；多位老師合上' '碩一必選修，PBL教學'
#  '臨藥所與基醫所合開' '中英文教學' '中英文授課，與解剖所合開' '中英文上課' '僅供碩三以上研究生修習' '中英文授課'
#  '同專題討論（二）之教師' '與醫學系合班' '基醫所、微免所合班' '基醫所，微免所合班' '與基醫所合班'
#  '限博士生選課；再生醫學科技學分學程(專業轉譯)' '分醫所、基醫所、口醫所合班' '基醫所，分醫所合班' '限博二以上學生選修'
#  '5:30上課/全英文/碩班與碩專班必選/再生醫學科技學分學程(專業轉譯)' '供博三以上研究生選修' '限博三以上學生選修' '博一學生必選'
#  '再生醫學科技學分學程(專業轉譯)' '醫院藥學組' '藥品動態組' '醫院藥學組，醫院實習' '上課教室:醫學院605' '碩一碩二合班'
#  '限碩三以上選修' '環醫所8063研討室' '環醫所8052研討室' '職業病個案診斷研究(二)(四)和環境與職業醫學實例討論(二)(四)合班'
#  '醫院門診' '職醫科8019研討室' '博一博二合班' '擔任課程助教' '限博三以上選修'
#  '博士班4年級以上選修/上課教室:環醫所8063研討室' '與專題討論(四)合班' '與專題討論(二)合班' '上課地點所研討室'
#  '先修臨床心理病理學' '先修復健心理學、臨床神經心理學' '先修臨床神經心理學' '先修過「社區高齡者心理健康促進」'
#  '黃惠玲w [1] 2-4；郭乃文w [2] N- 5；余睿羚w [3] 5-7 ；邱郁雯w[4]2-4；其餘督導(朱慶琳、蔡文玲、蘇倍儀)時間另行通知'
#  '醫院全時間實習' '先修過臨床神經心理學' '全英文' '再生醫學科技學分學程(基礎核心)(碩班必選/碩專必修)'
#  '與高等儀器分析(二)合開，再生醫學科技學分學程(專業轉譯)' '全英文/再生醫學科技學分學程(基礎核心)' '再生醫學科技學分學程(基礎核心)'
#  '碩專必選/再生醫學技術學程(專業轉譯)' '與口醫所合開'
#  '再生醫學科技學分學程(專業轉譯)/與再生醫學技術合開/限本所碩士班(含專班)修讀,且人數不超過25人'
#  '中研院簡正鼎教授負責/教室-跨領域研究大樓B100(限本學程學生修讀)' '中研院簡正鼎教授負責(限本學程學生修讀)'
#  '中研院姚季光助研究員主負責/上課地點中研院跨領域研究大樓B100(限本學程學生修讀)'
#  '上課地點：門診大樓8樓公衛所會議室，專題討論(二)、(四)合開' '上課地點：門診大樓8樓公衛所會議室，與專題討論（二）（四）合開'
#  '上課地點：門診大樓8樓公衛所08077研討室' '上課地點：門診大樓8樓公衛所08086研討室' '上課地點：門診大樓8樓公衛所會議室'
#  '醫技所與食安所合班' '供延畢生修' '隔週上課，限本系學生' '含海外實習，限本系學生' '全體教師授課．限延畢生修'
#  '國際碩士班課程，限本系學生' '國際碩士班課程，限本系學生（醫圖電腦室）' '國際碩士班課程' '國際博士班課程' '與護理所合開'
#  '大四可選' '臨床組必選' '次專科各自帶開，臨床組必選' '上課教室:醫學部門診' '與物理治療專題討論四合班' '此課程為大碩合開'
#  '上課教室:醫學院201' '上課時間及教室請洽授課教師' '請洽指導教授' '全體教師' '與碩班專題討論(二)合班上課'
#  '全體教師參與(上課教室:門診大樓8樓公衛所08077會議室)' '與博班專題討論(二)合班上課(上課教室:門診大樓8樓公衛所08077會議室)'
#  '與博班專題討論(二)(四)合班上課' '上課教室:門診大樓8樓公衛所08064討論室' '門診大樓8樓公衛所08077會議室'
#  '上課地點：公衛所08077會議室' '上課地點：門診大樓8樓公衛所08077會議室' '上課地點：門診大樓8樓公衛所08064研討室'
#  '上課教室:82-0523' '上課地點:81-0501' '上課地點：健照所會議室、與護理所合開' '上課教室:健照所會議室'
#  '此課程全所教師共同上課' '此課程需校外參訪，僅限研究所碩班修習' '限大三以上同學修課'
#  '需修滿15學分才能選修此課程，部分時段寒暑假校外實習 。' '醫學院10樓電腦教室上課' '醫學院10樓電腦教室'
#  '醫學院10樓電腦教室(82-1038)' '老化與生活學分學程'
#  '老化與生活學分學程。本課程為融入服務學習內含之專業課程，修習通過可免修服務學習。' '限選10人，第二階段開放選課'
#  '本學期有註冊，但未選修其他課程者必修。無上課時段，請與指導教授保持聯繫。'
#  '限碩士班丁組、原科法所、學士班之大三以上選修（學士班分類：特別法）。'
#  '限碩士班丁組、原科法所、學士班之大三以上選修（學士班分類：專題及實例研討）。'
#  '法學外文課程開放大三以上修課（學士班分類：法學外文），所有選修生應符合語文能力要求與授課老師規定，請注意開學考試公告。' '開放碩士班選修'
#  '限本系碩士在職專班選修，一般生不可選修。' '限本系碩士在職專班選修，一般生不可選修' '非本所學生，須修過基礎統計'
#  '外所學生須經授課教師確認統計基本知識，同意後才可選修本課程' '修過教育統計' '需經授課老師同意後得以選修'
#  '選課前須先email授課老師取得同意。' '電腦教室' '限選修過植物學講座系列課程']

# %% [markdown]
# 刪除不必要的欄位

# %%
print(df.shape)
if '學制' in df.columns:
    df = df[df['學制'] == '大學部']
    
if '必選修' in df.columns:
    df = df[df['必選修'] == '必修']

df = df[['開課單位', '星期', '開始時間', '結束時間', '課程類別']]

print(df.shape)
df.columns
# Out:
# (4978, 26)
# (2099, 5)
# Index(['開課單位', '星期', '開始時間', '結束時間', '課程類別'], dtype='object')

# %%
df['開課單位'].unique()[0:10]
# Out:
# array(['外國語言', '基礎國文', '通識中心', '中國文學系學士班', '外國語文學系學士班', '歷史學系學士班',
#        '台灣文學系學士班', '數學系學士班', '物理學系學士班', '化學系學士班'], dtype=object)

# %% [markdown]
# 資料中存在不是通識中心也非各科系的開課單位，例如：體育室、華語中心、服務學習等
#
# 依據 [國立成功大學通識課程選修要點](http://cge.ncku.edu.tw/p/404-1007-7830.php?Lang=zh-tw#%E5%9C%8B%E7%AB%8B%E6%88%90%E5%8A%9F%E5%A4%A7%E5%AD%B8%E9%80%9A%E8%AD%98%E8%AA%B2%E7%A8%8B%E9%81%B8%E4%BF%AE%E8%A6%81%E9%BB%9E(108%E5%AD%B8%E5%B9%B4%E5%BA%A6%E8%B5%B7%E5%85%A5%E5%AD%B8%E7%94%9F%E9%81%A9%E7%94%A8))，通識課包含「基礎國文」、「外國語言」、「領域通識」及「融合通識」，對應到資料中的開課單位為**基礎國文**、**外國語言**及**通識中心**
#
# 因此其他非系所名稱也非通識的開課單位，都不是我們這次要討論的範圍，刪掉

# %%
print(df.shape)
for i in ['體育室', '教育學程', '服務學習（三）', '共同科目英語授課', '華語中心']:
    df = df[df['開課單位'] != i]
print(df.shape)
# Out:
# (1907, 5)
# (1857, 5)

# %% [markdown]
# 為了方便，將上課時間做標籤編碼(label encoding)，07:10-08:00 為第一節，08:10-09:00為 第二節，以此類推

# %%
for i in range(15):
    df.replace([f'{i+7:02d}:10', f'{i+8:02d}:00'], i, inplace=True)

print(df['開始時間'].unique())
print(df['結束時間'].unique())
# Out:
# [2 6 3 8 5 1 7 9 '未定' 4 10 0 11]
# [3 7 4 9 5 2 10 8 '未定' 1 11 6 0 12 14 13]

# %% [markdown]
# 將時間未定的課程刪掉

# %%
print(df.shape)
df = df[df['開始時間'] != '未定']
df = df[df['結束時間'] != '未定']
print(df.shape)
# Out:
# (1777, 5)
# (1777, 5)
# [2, 3]

# %%
def is_clashed(class1, class2):
    ''' 判斷兩堂課是否衝堂 (pd.Series, pd.Series) => bool '''
    class1_time = range(class1['開始時間'], class1['結束時間'] + 1)
    return class2['開始時間'] in class1_time or class2['結束時間'] in class1_time

print(df.loc[1, :])
print(df.loc[10, :])

is_clashed(df.loc[1, :], df.loc[1, :])
# Out:
# 開課單位        外國語言
# 星期             一
# 開始時間           2
# 結束時間           3
# 課程類別    通識(外國語言)
# Name: 1, dtype: object
# 開課單位        外國語言
# 星期             一
# 開始時間           6
# 結束時間           7
# 課程類別    通識(外國語言)
# Name: 10, dtype: object
# True

# %% [markdown]
# ## 視覺化呈現
# 我們想知道以下幾個問題：
# 1. 通識課的時間分布
# 2. 各系必修的時間分布
# 3. 各系必修課撞了多少通識？
#
# [回頂部](#成大通識與各系必修撞課分析)

# %%
df['開課單位'].value_counts().head(10)
# Out:
# 通識中心            154
# 醫學系學士班          150
# 機械工程學系學士班       100
# 化學工程學系學士班        92
# 電機工程學系學士班        77
# 外國語言             67
# 外國語文學系學士班        56
# 基礎國文             42
# 材料科學及工程學系學士班     41
# 工業與資訊管理學系學士班     37
# Name: 開課單位, dtype: int64

# %% [markdown]
# ## 結果分析與討論
# [回頂部](#成大通識與各系必修撞課分析)
